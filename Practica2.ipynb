# %% [markdown]
# <a href="https://colab.research.google.com/github/vanessabriggith/python/blob/main/Practica2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

print('--------------LOADING DATASET------------------------')
url='/content/Heart.csv'
import pandas as pd
data = pd.read_csv(url)
print(data.head(5))
print(data.info())
print(data.describe())
print(data.shape)
print(data['sex'].unique())



#PLOTTING OF CLEANING+ DATASET
print('--------------PLOTTING DATASET----------------------')
import matplotlib.pyplot as plt

#data.plot(kind='box',subplots=True,layout=(4,4),sharex=False)
#plt.show()

#data.hist()
#plt.show()

print('--------------PERFOMING CLASSIFICATION TASK----------------------')
data=data.drop(['chol'],axis=1)
x=data.drop('target',axis=1)
print(x.info())
print('****')

#PREPROCESSING DATA INTO STANDAR SCALE
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
x=scaler.fit_transform(x)

#SPLITTING THE DATASET INTO TRAINING AND TESTING
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.75)

#from sklearn.ensemble import RandomForestClassifier
#model=RandomForestClassifier()
#model.fit(x_train,y_train)
#yPredictionOnTraining=model.predict(x_train)
#yPredictionOnTesting=model.predict(x_test)
#from sklearn import metrics
#print('TRAIN ACCURACY SCORE: {}'.format(metrics.accuracy_score(y_train,yPredictionOnTraining)))
#print('TEST ACCURACY SCORE: {}'.format(metrics.accuracy_score(y_test,yPredictionOnTesting)))
#print('CONFUSION MATRIX: \n{}'.format(metrics.confusion_matrix(y_test,yPredictionOnTesting)))


#from sklearn.ensemble import RandomForestClassifier
#from sklearn.linear_model import LogisticRegression
#model=LogisticRegression()
#model.fit(x_train,y_train)
#yPredictionOnTraining=model.predict(x_train)
#yPredictionOnTesting=model.predict(x_test)
#from sklearn import metrics
#print('TRAIN ACCURACY SCORE: {}'.format(metrics.accuracy_score(y_train,yPredictionOnTraining)))
#print('TEST ACCURACY SCORE: {}'.format(metrics.accuracy_score(y_test,yPredictionOnTesting)))
#print('CONFUSION MATRIX: \n{}'.format(metrics.confusion_matrix(y_test,yPredictionOnTesting)))


from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn import metrics

models=[RandomForestClassifier(), LogisticRegression(), RandomForestClassifier(),
        KNeighborsClassifier(),SVC(),GaussianNB(), DecisionTreeClassifier(),
        MLPClassifier(hidden_layer_sizes=(8,10,10,10),alpha=0.003,activation='relu',solver='adam',max_iter=500)]
accuracyList=[]
for model in models:
 model.fit(x_train,y_train)
 yPredictionOnTraining=model.predict(x_train)
 yPredictionOnTesting=model.predict(x_test)
 from sklearn import metrics
 print('TRAIN ACCURACY SCORE: {}'.format(metrics.accuracy_score(y_train,yPredictionOnTraining)))
 print('TEST ACCURACY SCORE: {}'.format(metrics.accuracy_score(y_test,yPredictionOnTesting)))
 print('CONFUSION MATRIX: \n{}'.format(metrics.confusion_matrix(y_test,yPredictionOnTesting)))
 accuracyList.append(metrics.accuracy_score(y_test,yPredictionOnTesting))
print(accuracyList)

Datasetcompare=pd.DataFrame({'Model':['RandomForestClassifier','LogisticRegression','RandomForestClassifier',
        'KNeighborsClassifier','SVC','GaussianNB','DecisionTreeClassifier',
        'MLPClassifier'],
'Accuracy':accuracyList})

#print(Datasetcompare.head(3))
print(Datasetcompare.sort_values(['Accuracy']))
# Out:
# --------------LOADING DATASET------------------------
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB
# None
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000
# (303, 14)
# [1 0]
# --------------PLOTTING DATASET----------------------
# --------------PERFOMING CLASSIFICATION TASK----------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   fbs       303 non-null    int64
#  5   restecg   303 non-null    int64
#  6   thalach   303 non-null    int64
#  7   exang     303 non-null    int64
#  8   oldpeak   303 non-null    float64
#  9   slope     303 non-null    int64
#  10  ca        303 non-null    int64
#  11  thal      303 non-null    int64
# dtypes: float64(1), int64(11)
# memory usage: 28.5 KB
# None
# ****
# TRAIN ACCURACY SCORE: 1.0
# TEST ACCURACY SCORE: 0.8026315789473685
# CONFUSION MATRIX:
# [[85 15]
#  [30 98]]
# TRAIN ACCURACY SCORE: 0.8666666666666667
# TEST ACCURACY SCORE: 0.7324561403508771
# CONFUSION MATRIX:
# [[73 27]
#  [34 94]]
# TRAIN ACCURACY SCORE: 1.0
# TEST ACCURACY SCORE: 0.7807017543859649
# CONFUSION MATRIX:
# [[84 16]
#  [34 94]]
# TRAIN ACCURACY SCORE: 0.88
# TEST ACCURACY SCORE: 0.7719298245614035
# CONFUSION MATRIX:
# [[ 74  26]
#  [ 26 102]]
# TRAIN ACCURACY SCORE: 0.9333333333333333
# TEST ACCURACY SCORE: 0.7631578947368421
# CONFUSION MATRIX:
# [[82 18]
#  [36 92]]
# TRAIN ACCURACY SCORE: 0.8266666666666667
# TEST ACCURACY SCORE: 0.6842105263157895
# CONFUSION MATRIX:
# [[71 29]
#  [43 85]]
# TRAIN ACCURACY SCORE: 1.0
# TEST ACCURACY SCORE: 0.7192982456140351
# CONFUSION MATRIX:
# [[86 14]
#  [50 78]]
# TRAIN ACCURACY SCORE: 1.0
# TEST ACCURACY SCORE: 0.7236842105263158
# CONFUSION MATRIX:
# [[78 22]
#  [41 87]]
# [0.8026315789473685, 0.7324561403508771, 0.7807017543859649, 0.7719298245614035, 0.7631578947368421, 0.6842105263157895, 0.7192982456140351, 0.7236842105263158]
#                     Model  Accuracy
# 5              GaussianNB  0.684211
# 6  DecisionTreeClassifier  0.719298
# 7           MLPClassifier  0.723684
# 1      LogisticRegression  0.732456
# 4                     SVC  0.763158
# 3    KNeighborsClassifier  0.771930
# 2  RandomForestClassifier  0.780702
# 0  RandomForestClassifier  0.802632
